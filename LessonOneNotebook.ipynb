# %% [markdown]
# ## Hello Brecker! This is your first file
#
# #### This is a Python Notebook. And you can run cells like the one below. Click the play button to the left of the cell.

# %%
print("Hello World!")
# Out:
# Hello World

# %% [markdown]
# #### Now lets start the basics:

# %%
# This is a comment, it explains code in the code.
# You know it is a comment because it starts with a "#"

# First lets make a variable:
x = 1

# Now print it - to make sure everythin works
print(x)
# Out:
# 1

# %% [markdown]
# #### You said you like math so strap in!

# %%
x = 1
y = 2

result = x + y

# Now what do you get?
print(result)
# Out:
# 3

# %% [markdown]
# #### That wasn't so bad. Lets do some real computer math now:

# %%
answer = 5 / 2

# so whats the answer, and how can you check?:

# %% [markdown]
# #### hmmmmm...

# %%
# Lets try and fix it:

# %% [markdown]
# ## GEOPANDAS!
# #### Wait what?
# ##### Try this: pip install geopandas

# %%
# you first have to install geopandas and some other "libraries"
# pip install geopandas
# pip install matplotlib
# pip install geodatasets


import geopandas as gpd
import matplotlib.pyplot as plt
import geodatasets

# %% [markdown]
# #### Now what does geopandas do?

# %%
world_path = geodatasets.get_path("geoda.naturalearth_countries")

print(world.head())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 world_path = geodatasets.get_path("geoda.naturalearth_countries")
#       3 print(world.head())
#
# File c:\Users\ethan\AppData\Local\Programs\Python\Python312\Lib\site-packages\geodatasets\api.py:86, in get_path(name)
#      49 def get_path(name):
#      50     """Get the absolute path to a file in the local storage.
#      51
#      52     If it’s not in the local storage, it will be downloaded.
#    (...)
#      84     '/Users/martin/Library/Caches/geodatasets/airbnb.zip'
#      85     """
# ---> 86     dataset = data.query_name(name)
#      87     if "members" in dataset.keys():
#      88         unzipped_files = CACHE.fetch(
#      89             dataset.filename, processor=pooch.Unzip(members=dataset.members)
#      90         )
#
# File c:\Users\ethan\AppData\Local\Programs\Python\Python312\Lib\site-packages\geodatasets\lib.py:120, in Bunch.query_name(self, name)
#     117 if name_clean in xyz_flat_lower:
#     118     return xyz_flat_lower[name_clean]
# --> 120 raise ValueError(f"No matching item found for the query '{name}'.")
#
# ValueError: No matching item found for the query 'geoda.naturalearth_countries'.

# %%
# initialize an empty figure and add an axis
fig = plt.figure(figsize=(20, 10))
ax = fig.add_subplot()

# plot a basic map of the world
world.plot(
    ax=ax,
    color="lightgray",
    edgecolor="black",
    alpha=0.5
)

# turn off axis ticks
ax.set_xticks([])
ax.set_yticks([])

# set the plot title
plt.title("Basic Map of World with GeoPandas")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 6
#       3 ax = fig.add_subplot()
#       5 # plot a basic map of the world
# ----> 6 world.plot(
#       7     ax=ax,
#       8     color="lightgray",
#       9     edgecolor="black",
#      10     alpha=0.5
#      11 )
#      13 # turn off axis ticks
#      14 ax.set_xticks([])
#
# NameError: name 'world' is not defined
